# %%
import gym
import random
import numpy as np
from collections import deque

import torch

from IPython import display
import matplotlib.pyplot as plt

import sys
sys.path.append('../')
from dqn_agent import Agent

# %%
env = gym.make('LunarLander-v2')
o_dim = env.observation_space.shape[0]
a_dim = env.action_space.n
print('State shape: ', o_dim)
print('Number of actions: ', a_dim)
# Out:
# State shape:  8
# Number of actions:  4

# %%
LR = 5e-4               # learning rate
LR_STEP_SIZE = 4
BATCH_SIZE = 64         # minibatch size
GAMMA = 0.99            # discount factor
TAU = 0.001             # for soft update of target parameters
BUFFER_SIZE = int(1e5)  # replay buffer size
UPDATE_EVERY = 1        
SEED = 1234

# %%
# parameters for training
NUM_EPISODES = 800
PRINT_EVERY = 50
TMAX = 1000

eps_start = 1.0
eps_end = 0.01
eps_decay = 0.995

# %% [markdown]
# ### 1. DQN

# %%
#LR = 5e-3               # learning rate
#LR_STEP_SIZE = 3

agent = Agent(o_dim, a_dim, lr = LR, lr_step_size = LR_STEP_SIZE, 
              batch_size = BATCH_SIZE, gamma = GAMMA, tau = TAU, buffer_size = BUFFER_SIZE,
              update_every = UPDATE_EVERY, seed = SEED, algorithm = "dqn")
print(agent.algorithm)

# %%
score_list = []
score_window = deque(maxlen = PRINT_EVERY)  
best_score = 0.0

eps = eps_start
for e in range(1, NUM_EPISODES+1):
    
    state = env.reset()
    score = 0
    for t in range(TMAX):
        action = agent.get_action(state, eps)
        next_state, reward, done, _ = env.step(action)
        agent.step(state, action, reward, next_state, done)
        state = next_state
        score += reward
        if done:
            break
            
    eps = max(eps_end, eps_decay*eps) # decrease epsilon
    score_window.append(score)
    mean_score = np.mean(score_window)
    score_list.append([score, mean_score])
    
    print('\r\rEpisode {}\tsum of rewards {:6.2f}'.format(e, mean_score), end = "")
    
    if e % PRINT_EVERY == 0:
        print('\rEpisode {}\tsum of rewards {:6.2f}'.format(e, mean_score))
        agent.scheduler.step()
        
        if mean_score >= best_score:
            print('\nmodel saved!')
            torch.save(agent.online_net.state_dict(), 'checkpoint.pth')
            best_score = mean_score
# Out:
# Episode 50	sum of rewards -171.95
# Episode 100	sum of rewards -104.96
# Episode 150	sum of rewards -75.287
# Episode 200	sum of rewards -53.96
# Episode 250	sum of rewards -36.70
# Episode 300	sum of rewards -16.08
# Episode 350	sum of rewards 100.09
#
# model saved!
# Episode 400	sum of rewards 174.96
#
# model saved!
# Episode 450	sum of rewards 177.45
#
# model saved!
# Episode 500	sum of rewards 191.16
#
# model saved!
# Episode 550	sum of rewards 209.41
#
# model saved!
# Episode 600	sum of rewards 208.62
# Episode 650	sum of rewards 185.33
# Episode 700	sum of rewards 208.78
# Episode 750	sum of rewards 206.46
# Episode 800	sum of rewards 204.92

# %%
score1 = np.asarray(score_list).T

fig = plt.figure()
plt.plot(np.arange(score1.shape[1]), score1[0], label = "DQN")
plt.plot(np.arange(score1.shape[1]), score1[1])
plt.ylabel('Total rewards')
plt.xlabel('Episode #')
plt.show()

# %%
# load checkpoint
agent.online_net.load_state_dict(torch.load('checkpoint.pth'))
# load to cpu and save the best weights
torch.save(agent.online_net.cpu().state_dict(), "dqn_LunarLander.pth")

# %% [markdown]
# ### 2. double DQN

# %%
agent = Agent(o_dim, a_dim, lr = LR, lr_step_size = LR_STEP_SIZE, 
              batch_size = BATCH_SIZE, gamma = GAMMA, tau = TAU, buffer_size = BUFFER_SIZE,
              update_every = UPDATE_EVERY, seed = SEED, algorithm = "double dqn")
print(agent.algorithm)

# %%
agent.algorithm
# Out:
# 'ddqn'

# %%
score_list = []
score_window = deque(maxlen = PRINT_EVERY)  
best_score = 0.0

eps = eps_start
for e in range(1, NUM_EPISODES+1):
    
    state = env.reset()
    score = 0
    for t in range(TMAX):
        action = agent.get_action(state, eps)
        next_state, reward, done, _ = env.step(action)
        agent.step(state, action, reward, next_state, done)
        state = next_state
        score += reward
        if done:
            break
            
    eps = max(eps_end, eps_decay*eps) # decrease epsilon
    score_window.append(score)
    mean_score = np.mean(score_window)
    score_list.append([score, mean_score])
    
    print('\r\rEpisode {}\tsum of rewards {:6.2f}'.format(e, mean_score), end = "")
    
    if e % PRINT_EVERY == 0:
        print('\rEpisode {}\tsum of rewards {:6.2f}'.format(e, mean_score))
        agent.scheduler.step()
        
        if mean_score >= best_score:
            print('\nmodel saved!')
            torch.save(agent.online_net.state_dict(), 'checkpoint.pth')
            best_score = mean_score
# Out:
# Episode 50	sum of rewards -169.75
# Episode 100	sum of rewards -110.80
# Episode 150	sum of rewards -73.601
# Episode 200	sum of rewards -44.85
# Episode 250	sum of rewards -18.04
# Episode 300	sum of rewards  -5.73
# Episode 350	sum of rewards  88.23
#
# model saved!
# Episode 400	sum of rewards 135.40
#
# model saved!
# Episode 404	sum of rewards 145.93

# %%
score2 = np.asarray(score_list).T

fig = plt.figure()
plt.plot(np.arange(score1.shape[1]), score1[0], label = "DQN")
plt.plot(np.arange(score1.shape[1]), score1[1])
plt.plot(np.arange(score2.shape[1]), score2[0], label = "double DQN")
plt.plot(np.arange(score2.shape[1]), score2[1])
plt.ylabel('Total rewards')
plt.xlabel('Episode #')
plt.show()

# %%
# load checkpoint
agent.online_net.load_state_dict(torch.load('checkpoint.pth'))
# load to cpu and save the best weights
torch.save(agent.online_net.cpu().state_dict(), "ddqn_LunarLander.pth")
